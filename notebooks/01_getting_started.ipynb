# %% [markdown]
# # NEA AI Agents - Getting Started
#
# This notebook demonstrates the basic setup and usage of the NEA AI agents.

# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# %%
# Import dependencies
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# %%
# Test basic LLM connection
llm = ChatOpenAI(model="gpt-4o", temperature=0)
response = llm.invoke([HumanMessage(content="Hello! Can you help with venture capital workflows?")])
print(response.content)

# %% [markdown]
# ## Next Steps
#
# 1. Explore the different agents in the `agents/` directory
# 2. Build custom tools in the `tools/` directory
# 3. Add your data files to the `data/` directory
